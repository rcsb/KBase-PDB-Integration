# %% [markdown]
# # Interactome3D
# Provides interactomes of 8 modeled organisms: *Arabidopsis thaliana, Caenorhabditis elegans, Escherichia coli, Drosophila melanogaster, Helicobacter pylori, Homo sapiens, Mus musculus and Saccharomyces cerevisiae*

# %% [markdown]
# * Update frequency : Twice a year (every 6 months)
# * Current version 2020_01
# * [Documentation](https://interactome3d.irbbarcelona.org/help.php)

# %% [markdown]
# ## Downloadable file format:
# <img src="files.png">

# %% [markdown]
# ## Modeling Strategy
#
# <img src = "modeling_strategy.png">

# %% [markdown]
# ## Modeling strategy
#
# The modeling pipeline can handle two types of input data: **a set of interactions provided by the user, or a list of organisms** for the modeling of either their entire interactomes or functional sub-parts of the interactomes.
#
# The first pipeline step collects structures for each individual protein in the set. The available experimental structures in the PDB is first identified and the structural coverage of the protein space is increased by using high-quality homology models. All the individual proteins are then classified into three categories: complete experimental structures (covering >80% of the length of the protein with 100% sequence identity), complete homology models (>80% coverage) and partial experimental structures or models (the rest). For the last category, the fragments are grouped together to cover the greatest possible length of the protein.
#
# Next experimentally determined structures of each interaction is identified, when these are not available, suitable templates is searched to model them. All pairs of contacting proteins sharing over 30% sequence identity with the protein pairs is considered to be modeled (target interaction) and apply a battery of filtering criteria. Those potential templates are then sorted with a scoring function that considers the completeness of the template and the sequence identity to the target. To improve structural coverage, partial templates involving structural domains in the two partners is also included on the basis of domain-domain interaction preferences observed in the PDB. The final models are built with Modeller, and the resulting structures at atomic resolution are checked for the presence of structural knots. Finally all the structures and models are ranked on the basis of their completeness and quality.

# %% [markdown]
# ## Homo sapiens: Representative Set
# [2020_01 release](https://interactome3d.irbbarcelona.org/downloadset.php?queryid=human&release=current&path=representative)

# %%
import pandas as pd
df = pd.read_csv('data/proteins.dat', sep = '\t')
df
# Out:
#        UNIPROT_AC  RANK_MAJOR  RANK_MINOR       TYPE PDB_ID CHAIN  SEQ_IDENT  \
# 0      A0A024R3Z2           1           0  Structure   1a5r     A      100.0
# 1      A0A024RAD5           1           0  Structure   6s7o     G      100.0
# 2      A0A024RAV5           1           0  Structure   2msd     B      100.0
# 3      A0A024RBG1           1           0      Model   1mk1     A       18.0
# 4      A0A075B5G3           1           0  Structure   4ov6     F      100.0
# ...           ...         ...         ...        ...    ...   ...        ...
# 16267      U5YJM1           1           0  Structure   2bnq     A      100.0
# 16268      V9H1G0           1           1  Structure   3u5o     P      100.0
# 16269      V9HW68           1           0      Model   1hzh     H       85.0
# 16270      V9JN72           1           0  Structure   5xtd     k      100.0
# 16271      W6CW81           1           1      Model   4o7q     A       70.0
#
#        COVERAGE  SEQ_BEGIN  SEQ_END  GA431   MPQS  ZDOPE  \
# 0         100.0          1      101  -1.00 -1.000  -1.00
# 1          90.1         42      452  -1.00 -1.000  -1.00
# 2          98.4          1      185  -1.00 -1.000  -1.00
# 3          91.7          5      170   0.98  1.135  -0.17
# 4         100.0          1       99  -1.00 -1.000  -1.00
# ...         ...        ...      ...    ...    ...    ...
# 16267      81.9         25      300  -1.00 -1.000  -1.00
# 16268      74.1          2       21  -1.00 -1.000  -1.00
# 16269      96.0         20      470   1.00  0.000   0.00
# 16270      99.0          1       97  -1.00 -1.000  -1.00
# 16271      73.4          1       83   1.00  1.669  -1.71
#
#                                       FILENAME
# 0                    A0A024R3Z2-EXP-1a5r_A.pdb
# 1                    A0A024RAD5-EXP-6s7o_G.pdb
# 2                    A0A024RAV5-EXP-2msd_B.pdb
# 3      A0A024RBG1-MDL-A0A024RBG1.17-1mk1_A.pdb
# 4                    A0A075B5G3-EXP-4ov6_F.pdb
# ...                                        ...
# 16267                    U5YJM1-EXP-2bnq_A.pdb
# 16268                    V9H1G0-EXP-3u5o_P.pdb
# 16269           V9HW68-MDL-V9HW68.6-1hzh_H.pdb
# 16270                    V9JN72-EXP-5xtd_k.pdb
# 16271           W6CW81-MDL-W6CW81.1-4o7q_A.pdb
#
# [16272 rows x 14 columns]

# %% [markdown]
# ## Understanding Protein Filename:
#     U5YJM1-EXP-2bnq_A.pdb = Uniprot_ac-Experimental_str-PDBID-Chain
#     V9HW68-MDL-V9HW68.6-1hzh_H.pdb = Uniprot_ac-Model-Uniprot_ac.Modelno.-PDBID-Chain

# %% [markdown]
# Note: Structures from PDB are also provided with quality scores used for evaluating models (from Modeller)
#
# ### Ranking of structures/models:
# **Structures with lower rank major index are, in general, of a higher quality.** The criteria used to rank structures and models for single proteins are the following:
#
# 1. **Complete experimental structures** are ranked first in the list and in order of **decreasing coverage**. A structure is considered to be complete if it covers more than 80% of the protein sequence length. **A complete experimental structure always has the rank minor index equal to 0.**
# 2. **Complete homology models** are ranked just after complete experimental structures in **decreasing order of sequence identity** of the template to the target. **A complete homology model always has the rank minor index equal to 0.**
# 3. **Partial experimental structures and homology models** are ranked after complete homology models. In this case Interactome3D tries to group together structures that cover, together, the largest portion of the protein sequence length. The different groups are generated by a greedy algorithm that takes into consideration the structures sorted by decreasing values of the following scoring function:
#
# <img src="Scoring_function.png">
#
# which takes into account the coverage of the structure and the sequence identity of the template to the target protein. The parameter alpha is set to 0.95 from empirical observations.
#
# **Every group of structures/models is assigned the same rank major number and different rank minor numbers in order of starting residue of the structure.
# When creating the representative set only the structures/models with rank major index equal to 1 are retained.** This means that also in the representative set we can have more than one structure for the same protein. This happens when a protein only has structures/models with a coverage lower than 80%. In this case, the program selects a group of (potentially) overlapping structures/models that together span the largest portion of the protein sequence.

# %%
#Looking at the models
df.loc[df["TYPE"]== "Model"]
# Out:
#        UNIPROT_AC  RANK_MAJOR  RANK_MINOR   TYPE PDB_ID CHAIN  SEQ_IDENT  \
# 3      A0A024RBG1           1           0  Model   1mk1     A       18.0
# 5      A0A075B6H7           1           0  Model   5dk3     A       80.0
# 6      A0A075B6H8           1           0  Model   1vge     L       73.0
# 7      A0A075B6H9           1           0  Model   2otu     A       71.0
# 8      A0A075B6I0           1           0  Model   1qok     A       38.0
# ...           ...         ...         ...    ...    ...   ...        ...
# 16257      Q9Y6Z7           1           1  Model   4yli     A       52.0
# 16258      Q9YNA8           1           1  Model   1bax             35.0
# 16265      U3KPV4           1           0  Model   1lzj     A       46.0
# 16269      V9HW68           1           0  Model   1hzh     H       85.0
# 16271      W6CW81           1           1  Model   4o7q     A       70.0
#
#        COVERAGE  SEQ_BEGIN  SEQ_END  GA431   MPQS  ZDOPE  \
# 3          91.7          5      170   0.98  1.135  -0.17
# 5          82.8         21      116   1.00  1.711  -1.09
# 6          81.2         23      117   1.00  1.642  -0.72
# 7          82.3         21      118   1.00  1.624  -1.01
# 8          99.2          2      122   1.00  1.326   0.05
# ...         ...        ...      ...    ...    ...    ...
# 16257      55.2        123      275   1.00  1.234  -0.76
# 16258      14.0          1       93   1.00  0.000   0.00
# 16265      85.0         44      332   1.00  1.180  -0.11
# 16269      96.0         20      470   1.00  0.000   0.00
# 16271      73.4          1       83   1.00  1.669  -1.71
#
#                                       FILENAME
# 3      A0A024RBG1-MDL-A0A024RBG1.17-1mk1_A.pdb
# 5       A0A075B6H7-MDL-A0A075B6H7.2-5dk3_A.pdb
# 6       A0A075B6H8-MDL-A0A075B6H8.1-1vge_L.pdb
# 7       A0A075B6H9-MDL-A0A075B6H9.1-2otu_A.pdb
# 8       A0A075B6I0-MDL-A0A075B6I0.1-1qok_A.pdb
# ...                                        ...
# 16257          Q9Y6Z7-MDL-Q9Y6Z7.10-4yli_A.pdb
# 16258            Q9YNA8-MDL-Q9YNA8.8-1bax_.pdb
# 16265           U3KPV4-MDL-U3KPV4.1-1lzj_A.pdb
# 16269           V9HW68-MDL-V9HW68.6-1hzh_H.pdb
# 16271           W6CW81-MDL-W6CW81.1-4o7q_A.pdb
#
# [7778 rows x 14 columns]

# %%
interactions = pd.read_csv('data/interactions.dat', sep = '\t')
interactions
# Out:
#             PROT1   PROT2  RANK_MAJOR  RANK_MINOR       TYPE PDB_ID BIO_UNIT  \
# 0      A0A024RAD5  P04843           1           0  Structure   6s7o        1
# 1      A0A024RAD5  P04844           1           0  Structure   6s7t        1
# 2      A0A024RAD5  P46977           1           0  Structure   6s7o        1
# 3      A0A024RAD5  P61803           1           0  Structure   6s7o        1
# 4      A0A024RAD5  Q8TCJ2           1           0  Structure   6s7t        1
# ...           ...     ...         ...         ...        ...    ...      ...
# 15021      Q9Y6U3  Q9Y6U3           1           0  Structure   5a1m        1
# 15022      Q9Y6X8  Q9Y6X8           1           0  Structure   3nau        1
# 15023      Q9Y6X9  Q9Y6X9           1           0  Structure   5of9        1
# 15024      Q9Y6Y0  Q9Y6Y0           1           0  Structure   6n34        1
# 15025      Q9Y6Y1  Q9Y6Y1           1           0  Structure   2cxk        3
#
#       CHAIN1 MODEL1  SEQ_IDENT1  ...  SEQ_END1  DOMAIN1  CHAIN2 MODEL2  \
# 0          G      0       100.0  ...       452        -       E      0
# 1          G      0       100.0  ...       452        -       F      0
# 2          G      0       100.0  ...       452        -       A      0
# 3          G      0       100.0  ...       452        -       D      0
# 4          G      0       100.0  ...       452        -       A      0
# ...      ...    ...         ...  ...       ...      ...     ...    ...
# 15021      A      0       100.0  ...       350        -       A      1
# 15022      B      0       100.0  ...       501        -       A      0
# 15023      B      0        97.6  ...       551        -       A      0
# 15024      B      0        95.2  ...       128        -       A      0
# 15025      E      0        98.8  ...       954        -       E      1
#
#       SEQ_IDENT2 COVERAGE2  SEQ_BEGIN2  SEQ_END2  DOMAIN2  \
# 0           98.9      93.2          29       594        -
# 1           95.4      41.5         369       630        -
# 2           93.8      99.1           7       705        -
# 3          100.0      97.3           4       113        -
# 4           93.8      91.2          63       815        -
# ...          ...       ...         ...       ...      ...
# 15021      100.0      14.5         247       350        -
# 15022      100.0       6.7         446       501        -
# 15023       98.0      53.0           5       551        -
# 15024       96.0      19.3           6       129        -
# 15025       98.8       4.9         873       954        -
#
#                                           FILENAME
# 0      A0A024RAD5-P04843-EXP-6s7o.pdb1-G-0-E-0.pdb
# 1      A0A024RAD5-P04844-EXP-6s7t.pdb1-G-0-F-0.pdb
# 2      A0A024RAD5-P46977-EXP-6s7o.pdb1-G-0-A-0.pdb
# 3      A0A024RAD5-P61803-EXP-6s7o.pdb1-G-0-D-0.pdb
# 4      A0A024RAD5-Q8TCJ2-EXP-6s7t.pdb1-G-0-A-0.pdb
# ...                                            ...
# 15021      Q9Y6U3-Q9Y6U3-EXP-5a1m.pdb1-A-0-A-1.pdb
# 15022      Q9Y6X8-Q9Y6X8-EXP-3nau.pdb1-B-0-A-0.pdb
# 15023      Q9Y6X9-Q9Y6X9-EXP-5of9.pdb1-B-0-A-0.pdb
# 15024      Q9Y6Y0-Q9Y6Y0-EXP-6n34.pdb1-B-0-A-0.pdb
# 15025      Q9Y6Y1-Q9Y6Y1-EXP-2cxk.pdb3-E-0-E-1.pdb
#
# [15026 rows x 22 columns]

# %% [markdown]
# ## Understanding Interaction Filename:
#
# A0A024RAD5-P04843-EXP-6s7o.pdb1-G-0-E-0.pdb = Protein1-Protein2-Experimental-PDBID-Chain1-Model1-Chain2-Model2

# %%
# Checking for entries of a seq A0A024RBG1 from proteins.dat in interactions.dat
interactions_A0A024RBG1 = interactions.loc[interactions['PROT1']=='A0A024RAD5']
interactions_A0A024RBG1
# Out:
#         PROT1   PROT2  RANK_MAJOR  RANK_MINOR       TYPE PDB_ID BIO_UNIT  \
# 0  A0A024RAD5  P04843           1           0  Structure   6s7o        1
# 1  A0A024RAD5  P04844           1           0  Structure   6s7t        1
# 2  A0A024RAD5  P46977           1           0  Structure   6s7o        1
# 3  A0A024RAD5  P61803           1           0  Structure   6s7o        1
# 4  A0A024RAD5  Q8TCJ2           1           0  Structure   6s7t        1
#
#   CHAIN1 MODEL1  SEQ_IDENT1  ...  SEQ_END1  DOMAIN1  CHAIN2 MODEL2 SEQ_IDENT2  \
# 0      G      0       100.0  ...       452        -       E      0       98.9
# 1      G      0       100.0  ...       452        -       F      0       95.4
# 2      G      0       100.0  ...       452        -       A      0       93.8
# 3      G      0       100.0  ...       452        -       D      0      100.0
# 4      G      0       100.0  ...       452        -       A      0       93.8
#
#   COVERAGE2  SEQ_BEGIN2  SEQ_END2  DOMAIN2  \
# 0      93.2          29       594        -
# 1      41.5         369       630        -
# 2      99.1           7       705        -
# 3      97.3           4       113        -
# 4      91.2          63       815        -
#
#                                       FILENAME
# 0  A0A024RAD5-P04843-EXP-6s7o.pdb1-G-0-E-0.pdb
# 1  A0A024RAD5-P04844-EXP-6s7t.pdb1-G-0-F-0.pdb
# 2  A0A024RAD5-P46977-EXP-6s7o.pdb1-G-0-A-0.pdb
# 3  A0A024RAD5-P61803-EXP-6s7o.pdb1-G-0-D-0.pdb
# 4  A0A024RAD5-Q8TCJ2-EXP-6s7t.pdb1-G-0-A-0.pdb
#
# [5 rows x 22 columns]

# %%
# Check if interaction table has entries for Sequence from proteins table
interactions_A0A024R3Z2 = interactions.loc[interactions['PROT2']=='A0A024R3Z2']
interactions_A0A024R3Z2
# Out:
# Empty DataFrame
# Columns: [PROT1, PROT2, RANK_MAJOR, RANK_MINOR, TYPE, PDB_ID, BIO_UNIT, CHAIN1, MODEL1, SEQ_IDENT1, COVERAGE1, SEQ_BEGIN1, SEQ_END1, DOMAIN1, CHAIN2, MODEL2, SEQ_IDENT2, COVERAGE2, SEQ_BEGIN2, SEQ_END2, DOMAIN2, FILENAME]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ## Accessing data through RESTful API
#
# Returns an XML file

# %%
import requests
from bs4 import BeautifulSoup
import json
from Bio.PDB import *

url_protein = "https://interactome3d.irbbarcelona.org/api/getProteinStructures?uniprot_ac=A0A5B9"
url_interaction = "https://interactome3d.irbbarcelona.org/api/getInteractionStructures?queryProt1=A0A5B9&queryProt2=P01848"

# %%
response = requests.get(url_protein)
print(type(response))
# Out:
# <class 'requests.models.Response'>

# %%
# Using BeautifuSoup object to parse content of the xml file
response_text = response.text
soup = BeautifulSoup(response_text, 'html.parser')
print(soup.prettify())
# Out:
# <?xml version="1.0"?>
# <interactome3d version="2020_01">
#  <protein_structure_list>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     72
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mja
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mja_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     34
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5eu6
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5eu6_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     68
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mjq
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mjq_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     59
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5fk9
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     96.1
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5fk9_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     60
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5fka
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     96.1
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5fka_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     50
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4udt
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     96.1
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4udt_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     17
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     1bd2
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-1bd2_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     33
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c08
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c08_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     19
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     2eys
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-2eys_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     39
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c0c
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c0c_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     3
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6cph
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6cph_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     62
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y2d
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y2d_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     45
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c0c
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c0c_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     31
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c0a
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c0a_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     43
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c0a
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c0a_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     4
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     2eyt
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-2eyt_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     55
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5ks9
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5ks9_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     24
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5hhm
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     98.4
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5hhm_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     35
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5hyj
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5hyj_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     76
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y4h
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y4h_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     81
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3tvm
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3tvm_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     66
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4zak
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4zak_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     18
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4p4k
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4p4k_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     36
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c0b
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c0b_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     13
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4n0c
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4n0c_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     9
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     2eyr
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-2eyr_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     5
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4wwk
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4wwk_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     47
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4ww1
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4ww1_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     25
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c09
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c09_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     38
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3kxf
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3kxf_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     78
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mj4
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mj4_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     30
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3kxf
#    </pdb_id>
#    <chain_id>
#     O
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3kxf_O.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     28
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5bs0
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5bs0_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     63
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3qux
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3qux_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     85
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4udu
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     95.3
#    </seq_id>
#    <coverage>
#     71.3
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     127
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4udu_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     16
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6cqq
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6cqq_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     1
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3o6f
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     98.5
#    </seq_id>
#    <coverage>
#     73
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     130
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3o6f_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     80
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6miy
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6miy_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     44
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c08
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c08_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     26
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3kxf
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3kxf_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     22
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3o6f
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     98.4
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3o6f_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     7
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6cql
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6cql_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     83
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mj6
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mj6_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     52
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5ksb
#    </pdb_id>
#    <chain_id>
#     F
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5ksb_F.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     14
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6cqr
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6cqr_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     87
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     1ao7
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     72.1
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-1ao7_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     20
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6cqq
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6cqq_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     11
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4mvb
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4mvb_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     15
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     2eyt
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-2eyt_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     86
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4onh
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     90.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4onh_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     46
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5hyj
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5hyj_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     65
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3ta3
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3ta3_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     75
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y2d
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y2d_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     57
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4c56
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4c56_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     23
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5hhm
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     98.4
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5hhm_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     56
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4c56
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4c56_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     37
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3kxf
#    </pdb_id>
#    <chain_id>
#     P
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3kxf_P.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     32
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5brz
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5brz_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     8
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4mxq
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4mxq_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     2
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3t0e
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     98.5
#    </seq_id>
#    <coverage>
#     73
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     130
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3t0e_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     48
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4nhu
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4nhu_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     82
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mjq
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mjq_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     12
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4ww2
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4ww2_B.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     69
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y4f
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y4f_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     64
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3o8x
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3o8x_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     29
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c07
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c07_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     70
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mji
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mji_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     54
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5hho
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5hho_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     73
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y4h
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y4h_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     40
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c09
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c09_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     74
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y16
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y16_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     27
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c07
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c07_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     6
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4n0c
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4n0c_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     67
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6miv
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6miv_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     58
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4p4k
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     97.6
#    </seq_id>
#    <coverage>
#     71.3
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     127
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4p4k_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     84
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     3o9w
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-3o9w_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     53
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5ksb
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5ksb_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     42
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5c0b
#    </pdb_id>
#    <chain_id>
#     J
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5c0b_J.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     71
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6mjj
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6mjj_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     21
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4n5e
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4n5e_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     77
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6miy
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6miy_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     10
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     6cqr
#    </pdb_id>
#    <chain_id>
#     E
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-6cqr_E.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     61
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y4k
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y4k_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     41
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5ksa
#    </pdb_id>
#    <chain_id>
#     D
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     72.5
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     129
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5ksa_D.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     51
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     5ks9
#    </pdb_id>
#    <chain_id>
#     F
#    </chain_id>
#    <seq_id>
#     96.9
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-5ks9_F.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     79
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4y4f
#    </pdb_id>
#    <chain_id>
#     H
#    </chain_id>
#    <seq_id>
#     94.5
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4y4f_H.pdb
#    </filename>
#   </protein_structure>
#   <protein_structure>
#    <uniprot_ac>
#     A0A5B9
#    </uniprot_ac>
#    <rank_major>
#     49
#    </rank_major>
#    <rank_minor>
#     1
#    </rank_minor>
#    <stype>
#     Structure
#    </stype>
#    <pdb_id>
#     4nhu
#    </pdb_id>
#    <chain_id>
#     B
#    </chain_id>
#    <seq_id>
#     97.7
#    </seq_id>
#    <coverage>
#     71.9
#    </coverage>
#    <prot_start>
#     1
#    </prot_start>
#    <prot_end>
#     128
#    </prot_end>
#    <ga341>
#     -1
#    </ga341>
#    <mpqs>
#     -1
#    </mpqs>
#    <zdope>
#     -1
#    </zdope>
#    <filename>
#     A0A5B9-EXP-4nhu_B.pdb
#    </filename>
#   </protein_structure>
#  </protein_structure_list>
# </interactome3d>

# %%
parser = PDBParser()
# structure = parser.get_structure("PHA-L", "1FAT.pdb")
